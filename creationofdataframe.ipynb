# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd 
data = {"name":["john","peter","lisa"],
         "age": [25,28,31],
         "salary":[30000,45000,25000]}
df= pd.DataFrame(data)
print(df)
# Out:
#     name  age  salary
# 0   john   25   30000
# 1  peter   28   45000
# 2   lisa   31   25000

# %%
import pandas as pd

data_list = [
    ["john", 25, 30000],
    ["peter", 28, 45000],
    ["lisa", 31, 25000]
]

columns = ['name', 'age', 'salary']

df2 = pd.DataFrame(data_list, columns=columns)

print(df2)
# Out:
#     name  age  salary
# 0   john   25   30000
# 1  peter   28   45000
# 2   lisa   31   25000

# %%
# agar dictionary se dataframe creTE KAROGE toh colunms name pehle se hi mention honge otherwise alag se set krne pdenge

# %% [markdown]
# # selection and indexing of columns

# %%
df2
# Out:
#     name  age  salary
# 0   john   25   30000
# 1  peter   28   45000
# 2   lisa   31   25000

# %%
df2['name']
df2[['name','age']]
# Out:
#     name  age
# 0   john   25
# 1  peter   28
# 2   lisa   31

# %%
#creating a new column

# %%
df2['city'] = ['chennai','hyderabad','delhi']
df2
# Out:
#     name  age  salary       city
# 0   john   25   30000    chennai
# 1  peter   28   45000  hyderabad
# 2   lisa   31   25000      delhi

# %%
# removing a column
df2.drop('city',axis=1,inplace=True)
df2
# Out:
#     name  age  salary
# 0   john   25   30000
# 1  peter   28   45000
# 2   lisa   31   25000

# %%
#selecting a row
df2.loc[0]
# Out:
# name       john
# age          25
# salary    30000
# Name: 0, dtype: object

# %%
#selecting a subset of row and column
df2.loc[0:1][['age','salary']]
# Out:
#    age  salary
# 0   25   30000
# 1   28   45000

# %%
#conditional selection
# selsect those people whose age above than 27
df2[df2['age']>27]
# Out:
#     name  age  salary
# 1  peter   28   45000
# 2   lisa   31   25000
